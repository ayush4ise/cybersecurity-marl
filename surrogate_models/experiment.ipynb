# %% [markdown]
# # Surrogate Model Agents for Cybersecurity Games

# %%
# !pip install gymnasium
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.9/953.9 kB 4.0 MB/s  0:00:0036m-:--:--
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.7/16.7 MB 7.1 MB/s  0:00:02m0:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [gymnasium]/4 [gymnasium]
# ...

# %%
# Calling or defining necessary functions
# exponential loss function, environment, defender model, attacker model,
# train model, run game

# %%
# Importing necessary libraries

# Call both params class and env class from environment
